# %%
# %pylab inline
import matplotlib.pyplot as plt
from scipy import fftpack
from scipy.fftpack import fft, fftfreq
import numpy as np
from numpy import pi
from scipy import fftpack
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['fftpack', 'f', 'fft']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
Im1 = pylab.imread("colesterol-1.tif")
Im1= Im1/140
fig = figure(1, figsize=(10.5,8.5))
imshow(Im1[:,:],cmap='gray')
plt.title('colesterol-1.tif - Imagen Original', fontsize=12)
[xf,yf]=shape(Im1)
print xf
print yf
# Out:
# 244
# 357

# %%
f = open('hessian.dat', 'w') 
print f

for i in range(1,xf-1):
    for j in range(1, yf-1):
        Hss=zeros((2,2))
        Hss[0,0]=Im1[i+1,j] + Im1[i-1,j] - Im1[i,j] - Im1[i,j]
        Hss[1,1]=Im1[i,j+1] + Im1[i,j-1]- Im1[i,j]- Im1[i,j]
        Hss[1,0]=(Im1[i+1,j+1]+Im1[i-1,j-1]+Im1[i,j]+Im1[i,j]-Im1[i+1,j]-Im1[i-1,j]-Im1[i,j+1]-Im1[i,j-1])/2.0
        Hss[0,1]=Hss[1,0]
        eigenvalues, eigenvectors = eig(Hss)
        for k in range(0,size(eigenvalues)):
            f.write(str(eigenvalues[k]))
            f.write(' ')
        f.write(str(eigenvectors[0,0]))
        f.write(' ')
        f.write(str(eigenvectors[1,0]))
        f.write(' ')
        f.write(str(eigenvectors[0,1]))
        f.write(' ')
        f.write(str(eigenvectors[1,1]))
        f.write(' ')
        f.write('\n')
# Out:
# <open file 'hessian.dat', mode 'w' at 0x10713b660>

# %%
Im2 = zeros((xf, yf))
for i in range(1,xf-1):
    for j in range(1, yf-1):
        Hss=zeros((2,2))
        Hss[0,0]=Im1[i+1,j] + Im1[i-1,j] - Im1[i,j] - Im1[i,j]
        Hss[1,1]=Im1[i,j+1] + Im1[i,j-1]- Im1[i,j]- Im1[i,j]
        Hss[1,0]=(Im1[i+1,j+1]+Im1[i-1,j-1]+Im1[i,j]+Im1[i,j]-Im1[i+1,j]-Im1[i-1,j]-Im1[i,j+1]-Im1[i,j-1])/2.0
        Hss[0,1]=Hss[1,0]
        eigenvalues, eigenvectors = eig(Hss)
        d= amax(eigenvalues) /1000
        Im2[i,j]=255*d
fig = figure(1, figsize=(10.5,8.5))
imshow(Im2[:,:],cmap='gray')

# %%
img = pylab.imread("20_popc_cho009-1.tif")
img = img/90
fig = figure(1, figsize=(10.5,8.5))
imshow(img[:,:], cmap = cm.Greys_r)
plt.title('Imagen Original', fontsize=12)
[xf,yf]=shape(img)
print xf
print yf
# Out:
# 560
# 512

# %%
Im2 = zeros((xf, yf))
for i in range(1,xf-1):
    for j in range(1, yf-1):
        Hss=zeros((2,2))
        Hss[0,0]=img[i+1,j] + img[i-1,j] - img[i,j] - img[i,j]
        Hss[1,1]=img[i,j+1] + img[i,j-1]- img[i,j]- img[i,j]
        Hss[1,0]=(img[i+1,j+1]+img[i-1,j-1]+img[i,j]+img[i,j]-img[i+1,j]-img[i-1,j]-img[i,j+1]-img[i,j-1])/2.0
        Hss[0,1]=Hss[1,0]
        eigenvalues, eigenvectors = eig(Hss)
        d= amax(eigenvalues) /1000
        Im2[i,j]=255*d
fig = figure(1, figsize=(10.5,8.5))
imshow(Im2[:,:],cmap='gray')

# %%
IMg = pylab.imread("ves_full_150_002-1.tif")
IMg = IMg/110
fig = figure(1, figsize=(10.5,8.5))
imshow(IMg[:,:], cmap = cm.Greys_r)
plt.title('Imagen Original', fontsize=12)
[xf,yf]=shape(IMg)
print xf
print yf
# Out:
# 576
# 544

# %%
Im2 = zeros((xf, yf))
for i in range(1,xf-1):
    for j in range(1, yf-1):
        Hss=zeros((2,2))
        Hss[0,0]=IMg[i+1,j] + IMg[i-1,j] - IMg[i,j] - IMg[i,j]
        Hss[1,1]=IMg[i,j+1] + IMg[i,j-1]- IMg[i,j]- IMg[i,j]
        Hss[1,0]=(IMg[i+1,j+1]+IMg[i-1,j-1]+IMg[i,j]+IMg[i,j]-IMg[i+1,j]-IMg[i-1,j]-IMg[i,j+1]-IMg[i,j-1])/2.0
        Hss[0,1]=Hss[1,0]
        eigenvalues, eigenvectors = eig(Hss)
        d= amax(eigenvalues) /1000
        Im2[i,j]=255*d
fig = figure(1, figsize=(10.5,8.5))
imshow(Im2[:,:],cmap='gray')

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import interpolate
t = np.arange(0, 1.1, .1)
x = np.sin(2*np.pi*t)
y = np.cos(2*np.pi*t)
tck,u = interpolate.splprep([x,y], s=0)
unew = np.arange(0, 1.01, 0.01)
out = interpolate.splev(unew, tck)
plt.figure()
plt.plot(x, y, 'x', out[0], out[1], np.sin(2*np.pi*unew), np.cos(2*np.pi*unew), x, y, 'b')
plt.legend(['Linear', 'Cubic Spline', 'True'])
plt.axis([-1.05, 1.05, -1.05, 1.05])
plt.title('Spline of parametrically-defined curve')
plt.show()
